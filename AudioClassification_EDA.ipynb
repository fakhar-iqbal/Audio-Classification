# %% [markdown]
# ## Audio Classification EDA using Machine Learning
# In this Project,we will be using Librosa library to analyse audio. We will also be using Scipy here.

# %%
# !pip install librosa

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename = '207211-2-0-100.wav'

# %%
plt.figure(figsize=(14,5))
import IPython.display as ipd

# %% [markdown]
# ### Analysing

# %%
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa
import librosa.display

# %%
data, sample_rate=librosa.load(filename)

# %%
data
# Out:
# array([-0.00362221, -0.00611693, -0.00707534, ..., -0.00164195,
#        -0.00067317, -0.00427378], dtype=float32)

# %%
sample_rate
# Out:
# 22050

# %% [markdown]
# ## Displaying Audio spectogram

# %%
S = librosa.stft(data)   #creating spectogram

# %%
import numpy as np

# %%
librosa.display.specshow(librosa.amplitude_to_db(S,ref=np.max))
# Out:
# <ipython-input-23-372ff13691a7>:1: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   librosa.display.specshow(librosa.amplitude_to_db(S,ref=np.max))

# %%
second = '197318-6-7-0.wav'

# %%
ipd.Audio(second)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# showing in spectogram

# %%
data2,sample_rate2 = librosa.load(second)
S2 = librosa.stft(data2)

# %%
sample_rate2
# Out:
# 22050

# %%
librosa.display.specshow(librosa.amplitude_to_db(S2,ref=np.max))
# Out:
# <ipython-input-31-a319d34c0e09>:1: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   librosa.display.specshow(librosa.amplitude_to_db(S2,ref=np.max))

# %%
from scipy.io import wavfile as wav

# %%
wave_sample_rate, audio_data = wav.read(filename)

# %%
audio_data
# Out:
# array([[-12946944,  -8009984],
#        [-14324224,  -9391616],
#        [-14127360, -10745600],
#        ...,
#        [-10757888,   -146432],
#        [-14765824,  -2915072],
#        [-17710848,  -5829120]], dtype=int32)

# %%
plt.plot(audio_data)

# we have two points since this is the data returned by scipy, in sterio form
